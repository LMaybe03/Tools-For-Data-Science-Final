# %% [markdown]
# #My Jupyter Notebook on Watson Studio

# %% [markdown]
# **Liezl Myburgh**
# *Teacher*

# %% [markdown]
# _I am interested in Data Science because of the vast possibilities it has to offer._ _Data Science can change the world, and I want to be part of that change._

# %% [markdown]
# The code will print "Hello World"

# %%
Code = "Hello World"
print(Code)
# Out:
# Hello World

# %% [markdown]
# - Apple
# - Pear
# - Watermelon
# ***
# ![IBM%20logo.png](attachment:IBM%20logo.png)
